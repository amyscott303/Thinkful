# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
article=pd.read_csv('WELLCOME_APCspend2013_forThinkful.csv',encoding = 'ISO-8859-1')
display (data)
# Out:
#                             PMID/PMCID  \
# 0                                  NaN
# 1                           PMC3679557
# 2                23043264  PMC3506128
# 3                  23438330 PMC3646402
# 4                 23438216 PMC3601604
# 5                           PMC3579457
# 6                           PMC3709265
# 7                 23057412 PMC3495574
# 8                    PMCID: PMC3780468
# 9                    PMCID: PMC3621575
# 10                   PMCID: PMC3739413
# 11                   PMCID: PMC3530961
# 12                   PMCID: PMC3624797
# 13                          PMC3413243
# 14                          PMC3694353
# 15                          PMC3572711
# 16                            22610094
# 17                   PMCID: PMC3586974
# 18        23455506  PMCID: PMC3607399
# 19          PMID: 24015914 PMC3833349
# 20                       : PMC3805332
# 21                                 NaN
# 22            PMCID:\n    PMC3656742\n
# ...

# %%
article.dtypes
# Out:
# PMID/PMCID                                             object
# Publisher                                              object
# Journal title                                          object
# Article title                                          object
# COST (£) charged to Wellcome (inc VAT when charged)    object
# dtype: object

# %%
article ['cost_string']= article['COST (£) charged to Wellcome (inc VAT when charged)']

# %%
article['cost'] = article.cost_string.str.replace('£','')
article['cost'] = article.cost.str.replace('$','')

# %%
articlecost =data['cost'].astype(np.float)

# %%
articlecost.describe()
# Out:
# count      2127.000000
# mean      24067.339972
# std      146860.665559
# min           0.000000
# 25%        1280.000000
# 50%        1884.010000
# 75%        2321.305000
# max      999999.000000
# Name: cost, dtype: float64

# %%
#msk rows for 999999- median instead of mean?
#use PMID for journal instead of journal titles

# %%
print(np.median(articlecost))
# Out:
# 1884.01

# %%
grouped_by = article.groupby(['Publisher','cost'])
row_count = grouped_by.cost.count()
msk = (row_count <= 999990)

# %%
grouped_by.cost.describe()[msk]
# Out:
#                                                       count     mean  std  \
# Publisher                                    cost
# ACS                                          642.56     1.0   642.56  NaN
#                                              649.33     1.0   649.33  NaN
#                                              669.64     1.0   669.64  NaN
#                                              685.88     1.0   685.88  NaN
#                                              2367.95    1.0  2367.95  NaN
#                                              2381.04    1.0  2381.04  NaN
#                                              2392.20    1.0  2392.20  NaN
# ACS (Amercian Chemical Society) Publications 1287.20    1.0  1287.20  NaN
#                                              1294.59    1.0  1294.59  NaN
#                                              1294.78    1.0  1294.78  NaN
#                                              1324.66    1.0  1324.66  NaN
# ...

# %% [markdown]
# Most common journals are:  1.ASBMB 2. Wiley/Blackwell 3. ACS- American Chemical Society  4. Wolters Kluwer 5. Public Service

# %%
Median= 1884.01 STD= NaN Mean=
